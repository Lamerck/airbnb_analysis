# %% [markdown]
# ### Data Visualization for EDA with matplotlib library
# * Define matplotlib
# * Features of matplotlib
# * Application of matplotlib

# %% [markdown]
# Matplotlib is a data visulaixzation library in **python** with a number of functions that can

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
airbnb = pd.read_csv("airbnb.csv")

# %%
airbnb.head()
# Out:
#       id                                            name  host_id  host_name  \
# 0  10595             96m2, 3BR, 2BA, Metro, WI-FI etc...    37177  Emmanouil
# 1  10990    Athens Quality Apartments - Deluxe Apartment    37177  Emmanouil
# 2  10993              Athens Quality Apartments - Studio    37177  Emmanouil
# 3  10995  AQA-No2 1-bedroom, smart tv, fiber connection,    37177  Emmanouil
# 4  27262              54m2, 1-br, cable tv, wi-fi, metro    37177  Emmanouil
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98863   23.76527  Entire home/apt
# 1                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98903   23.76448  Entire home/apt
# 2                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98888   23.76473  Entire home/apt
# 3                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98903   23.76448  Entire home/apt
# 4                  NaN   ΑΜΠΕΛΟΚΗΠΟΙ  37.98924   23.76500  Entire home/apt
#
# ...

# %%
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
airbnb.isna().sum()
# Out:
# id                                    0
# name                                  3
# host_id                               0
# host_name                             7
# neighbourhood_group               11321
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        2033
# reviews_per_month                  2033
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                            1570
# dtype: int64

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11321 entries, 0 to 11320
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              11321 non-null  int64
#  1   name                            11318 non-null  object
#  2   host_id                         11321 non-null  int64
#  3   host_name                       11314 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   11321 non-null  object
#  6   latitude                        11321 non-null  float64
#  7   longitude                       11321 non-null  float64
#  8   room_type                       11321 non-null  object
#  9   price                           11321 non-null  int64
#  10  minimum_nights                  11321 non-null  int64
#  11  number_of_reviews               11321 non-null  int64
# ...

# %%
import seaborn as sns

# %% [raw]
# # Plot 2: Room Type vs. Price
# plt.figure(figsize=(10, 6))
# sns.boxplot(x='room_type', y='price', data=airbnb)
# plt.title('Room Type vs. Price(Box Plot)')
# plt.xlabel('Room Type')
# plt.ylabel('Price')
# plt.savefig('Room Type vs. Price2.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [raw]
# plt.figure(figsize=(10, 6))
# sns.violinplot(x='room_type', y='price', data=airbnb)
# plt.title('Room Type vs. Price')
# plt.xlabel('Room Type')
# plt.ylabel('Price')
# plt.savefig('Room Type vs. Price.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [raw]
# # Plot 3: Reviews per Month vs. Price
# plt.figure(figsize=(10, 6))
# sns.scatterplot(x='reviews_per_month', y='price', data=airbnb)
# plt.title('Reviews per Month vs. Price')
# plt.xlabel('Reviews per Month')
# plt.ylabel('Price')
# plt.show()

# %% [raw]
# plt.figure(figsize=(10, 6))
# sns.regplot(x='reviews_per_month', y='price', data=airbnb)
# plt.title('Reviews per Month vs. Price (Regression)')
# plt.xlabel('Reviews per Month')
# plt.ylabel('Price')
# plt.show()

# %% [raw]
# # Plot 4: Availability throughout the Year
# plt.figure(figsize=(10, 6))
# sns.kdeplot(airbnb['availability_365'], shade=True)
# plt.title('Density of Availability Throughout the Year')
# plt.xlabel('Availability (days)')
# plt.ylabel('Density')
# plt.show()

# %% [raw]
# # Plot 5: Geographical Distribution
# plt.figure(figsize=(10, 6))
# sns.scatterplot(x='longitude', y='latitude', hue='neighbourhood', data=airbnb)
# plt.title('Geographical Distribution of Listings')
# plt.xlabel('Longitude')
# plt.ylabel('Latitude')
# plt.show()

# %% [raw]
# # Cleaning steps
# airbnb['reviews_per_month'].fillna(0, inplace=True)
# airbnb['last_review'] = pd.to_datetime(airbnb['last_review'], errors='coerce')
# airbnb['license'].fillna('Unknown', inplace=True)
#
# # Plot 1: Correlation Heatmap
# #plt.figure(figsize=(12, 8))
# #corr = airbnb.corr()
# #sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
# #plt.title('Correlation Heatmap')
# #plt.show()
#
# # Plot 2: Pairplot
# sns.pairplot(airbnb, vars=['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365'])
# plt.suptitle('Pairplot of Numerical Features', y=1.02)
# plt.savefig('Pairplot of Numerical Features.png', dpi=300, bbox_inches='tight')
# plt.show()
#
# # Plot 3: Count Plot for Room Types
# plt.figure(figsize=(10, 6))
# sns.countplot(x='room_type', data=airbnb)
# plt.title('Count Plot of Room Types')
# plt.xlabel('Room Type')
# plt.ylabel('Count')
# plt.show()
#
# # Plot 4: Count Plot for Neighborhoods (top 10 neighborhoods)
# top_neighbourhoods = airbnb['neighbourhood'].value_counts().nlargest(10).index
# plt.figure(figsize=(10, 6))
# sns.countplot(y='neighbourhood', data=airbnb[airbnb['neighbourhood'].isin(top_neighbourhoods)], order=top_neighbourhoods)
# plt.title('Count Plot of Top 10 Neighborhoods')
# plt.xlabel('Count')
# plt.ylabel('Neighborhood')
# plt.show()
#
# # Plot 5: Facet Grid of Room Type vs. Price by Neighborhood
# g = sns.FacetGrid(airbnb[airbnb['neighbourhood'].isin(top_neighbourhoods)], col='neighbourhood', col_wrap=4, height=4)
# g.map(sns.boxplot, 'room_type', 'price')
# g.add_legend()
# plt.subplots_adjust(top=0.9)
# g.fig.suptitle('Room Type vs. Price by Neighborhood')
# plt.show()
#
# # Plot 6: Heatmap for Price and Availability
# plt.figure(figsize=(12, 8))
# pivot_table = airbnb.pivot_table(index='price', columns='availability_365', aggfunc='size', fill_value=0)
# sns.heatmap(pivot_table, cmap='viridis')
# plt.title('Heatmap of Price vs. Availability')
# plt.xlabel('Availability (days)')
# plt.ylabel('Price')
# plt.show()
#
# # Plot 7: Time Series Plot for Number of Reviews over Time
# airbnb.set_index('last_review', inplace=True)
# monthly_reviews = airbnb['number_of_reviews'].resample('M').sum()
# plt.figure(figsize=(12, 6))
# sns.lineplot(x=monthly_reviews.index, y=monthly_reviews.values)
# plt.title('Time Series of Number of Reviews')
# plt.xlabel('Date')
# plt.ylabel('Number of Reviews')
# plt.savefig('Time Series of Number of Reviews.png', dpi=300, bbox_inches='tight')
# plt.show()
#
# # Reset the index after resampling
# airbnb.reset_index(inplace=True)
#
# # Plot 8: Scatter Plot with Size and Color (Price vs. Availability)
# plt.figure(figsize=(12, 8))
# sns.scatterplot(x='availability_365', y='price', size='number_of_reviews', hue='room_type', data=airbnb, alpha=0.6)
# plt.title('Scatter Plot of Price vs. Availability')
# plt.xlabel('Availability (days)')
# plt.ylabel('Price')
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
# plt.savefig('Scatter Plot of Price vs. Availability.png', dpi=300, bbox_inches='tight')
# plt.show()
#
# # Plot 9: Categorical Plot for Room Types and Reviews per Month
# plt.figure(figsize=(10, 6))
# sns.catplot(x='room_type', y='reviews_per_month', kind='bar', data=airbnb)
# plt.title('Reviews per Month by Room Type')
# plt.xlabel('Room Type')
# plt.ylabel('Reviews per Month')
# plt.savefig('Reviews per Month by Room Type.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [raw]
# # Cleaning steps
# airbnb['reviews_per_month'].fillna(0, inplace=True)
# airbnb['last_review'] = pd.to_datetime(airbnb['last_review'], errors='coerce')
# airbnb['license'].fillna('Unknown', inplace=True)
#
# # Plot 10: Joint Plot for Bivariate Distribution (Price vs. Reviews per Month)
# plt.figure(figsize=(10, 6))
# sns.jointplot(x='price', y='reviews_per_month', data=airbnb, kind='scatter', height=8, marginal_kws=dict(bins=50, fill=True))
# plt.suptitle('Joint Plot of Price vs. Reviews per Month', y=1.02)
# plt.savefig('Joint Plot.png', dpi=300, bbox_inches='tight')
# plt.show()
#
# # Plot 14: Point Plot for Room Type and Average Price
# plt.figure(figsize=(10, 6))
# sns.pointplot(x='room_type', y='price', data=airbnb, capsize=.2, markers='o', linestyles='-', estimator='mean')
# plt.title('Point Plot of Average Price by Room Type')
# plt.xlabel('Room Type')
# plt.ylabel('Average Price')
# plt.savefig('Point Plot.png', dpi=300, bbox_inches='tight')
# plt.show()
#
# # Plot 15: Pairplot with Hue (Colored by Room Type)
# plt.figure(figsize=(12, 10))
# sns.pairplot(airbnb, vars=['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365'], hue='room_type')
# plt.suptitle('Pairplot of Numerical Features Colored by Room Type', y=1.02)
# plt.savefig('Pairplot2.png', dpi=300, bbox_inches='tight')
# plt.show()
