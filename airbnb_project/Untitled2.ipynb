# %%
import pandas as pd

# %%
airbnb = pd.read_csv('airbnb.csv')

# %%
airbnb.head(10)
# Out:
#         id                                               name   host_id  \
# 0    10595                96m2, 3BR, 2BA, Metro, WI-FI etc...     37177
# 1    10990       Athens Quality Apartments - Deluxe Apartment     37177
# 2    10993                 Athens Quality Apartments - Studio     37177
# 3    10995     AQA-No2 1-bedroom, smart tv, fiber connection,     37177
# 4    27262                 54m2, 1-br, cable tv, wi-fi, metro     37177
# 5   767272                        Luxury Gallery garden house    964919
# 6  2219385  Modern central flat Old Olympic stadium-Acropolis  11322414
# 7    28186             ❤️Deluxe central loft near Acropolis❤️    121318
# 8  2263679                   A great venue with classic decor  11548006
# 9   780733                TOP KOLONAKI...Top Kolonaki Centre.    314308
#
#           host_name  neighbourhood_group                     neighbourhood  \
# 0         Emmanouil                  NaN                       ΑΜΠΕΛΟΚΗΠΟΙ
# ...

# %%
import matplotlib.pyplot as plt
x5 = airbnb['availability_365']
y5 = airbnb['price']
plt.scatter(x5, y5, alpha=0.2)
